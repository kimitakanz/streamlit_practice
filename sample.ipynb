# %%
import streamlit as st
import numpy as np
import pandas as pd
# Out:
# 2022-06-13 06:37:33.208 INFO    numexpr.utils: NumExpr defaulting to 4 threads.

# %%
df = pd.DataFrame(
    np.random.rand(20,3),
    columns=['a','b','c']
)
df
# Out:
#            a         b         c
# 0   0.255363  0.988960  0.528067
# 1   0.841099  0.065525  0.900940
# 2   0.558676  0.842563  0.233899
# 3   0.465426  0.079929  0.094438
# 4   0.130369  0.643465  0.217732
# 5   0.635809  0.361809  0.303587
# 6   0.507319  0.759968  0.809353
# 7   0.047993  0.477502  0.599861
# 8   0.133265  0.514428  0.005643
# 9   0.033077  0.184653  0.463578
# 10  0.234938  0.918555  0.685745
# 11  0.372719  0.616249  0.125034
# 12  0.624625  0.323968  0.381343
# 13  0.380216  0.779089  0.978787
# 14  0.524009  0.183436  0.538274
# 15  0.448232  0.460573  0.634018
# 16  0.663600  0.902769  0.088751
# 17  0.032699  0.328507  0.743405
# 18  0.135655  0.215886  0.814964
# 19  0.704029  0.045748  0.545411
